# %%
def printme(str):
    # this is a print function
    print(str);
    return;

printme("I'm first call to user defined ffunction!");
printme("Again second call to the same function!");
# Out:
# I'm first call to user defined ffunction!
# Again second call to the same function!

# %%
def changeme( mylist ):
    # This changes a passed list
    mylist.apppend([1,2,3,4])
    print ("Values inside the function: ", mylist)
    return
mylist = [10,20,30]
changeme( mylist )
print("values outside the functon: ", mylist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 7
#       5     return
#       6 mylist = [10,20,30]
# ----> 7 changeme( mylist )
#       8 print("values outside the functon: ", mylist)
#
# Cell In[8], line 3, in changeme(mylist)
#       1 def changeme( mylist ):
#       2     # This changes a passed list
# ----> 3     mylist.apppend([1,2,3,4])
#       4     print ("Values inside the function: ", mylist)
#       5     return
#
# AttributeError: 'list' object has no attribute 'apppend'

# %%
def changeme( mylist ):
    # This changes a passed list
    mylist = [1,2,3,4];
    print ("Values inside the function: ", mylist)
    return
mylist = [10,20,30]
changeme( mylist )
print("values outside the functon: ", mylist)
# Out:
# Values inside the function:  [1, 2, 3, 4]
# values outside the functon:  [10, 20, 30]

# %%
def printme( str ):
    # this prints a passed string
    print( str );
    return;
printme(5);    

def printme( str ):
    # this prints a passed string
    print (str);
    return;
printme( str = "My String");
# Out:
# 5
# My String

# %%
def printinfo( name, age ):
    # Test function
    print ("Name: ", name);
    print ("Age: ", age);
    return;
printinfo( age=50, name = "Nikky");
# Out:
# Name:  Nikky
# Age:  50

# %%
def printinfo(name, age = 35):
    # Test function
    print ("Name: ", name);
    print ("Age: ", age);
    return;
printinfo( age = 50, name = "Nikky" );
printinfo( name = "Nikky")
# Out:
# Name:  Nikky
# Age:  50
# Name:  Nikky
# Age:  35

# %%
def printinfo( arg1, *vartuple ):
    # This is test
    print ("Output is: ")
    print (arg1)
    for var in vartuple:
        print (var)
        return;
printinfo( 10 );
printinfo( 70, 60, 50 );
# Out:
# Output is:
# 10
# Output is:
# 70
# 60

# %%
total = 50; # This is a global variable.
def sum(arg1, arg2):
    # Adds both the parameters
    total = arg1 + arg2;
    print ("Inside the function local total; ", total)
    return total;
# Now you can call sum function 
sum(10, 20);
print ("outside the function global total: ", total)
# Out:
# Inside the function local total;  30
# outside the function global total:  50

# %%
def swap(x, y):
    global a 
    a = "Lawal"
    x,y = y,x
    b = "Chris"
    b = "Edward"
    c = "Lola"
    print(a,b,x,y)
    a = "Mary"
swap("Tina", "Tolu")
print(a)
# Out:
# Lawal Edward Tolu Tina
# Mary
