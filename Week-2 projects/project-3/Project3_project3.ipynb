# %%
import pandas as pd

# %%
# girls data

girls_data ={
    "Name": ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"],
    "Age": [17, 16, 17, 18, 16, 18, 17, 20, 19, 17],
    "Height": [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5],
    "Scores": [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]
}

# boys data
boys_data = {
    "Name": ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"],
    "Age": [19, 16, 18, 17, 20, 19, 16, 18, 17, 19],
    "Height": [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7],
    "Score": [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]
}

df_girls = pd.DataFrame(girls_data)
df_boys = pd.DataFrame(boys_data)

df_final = pd.concat([df_girls, df_boys], ignore_index=True)
print(df_final)
# Out:
#        Name  Age  Height  Scores  Score
# 0    Evelyn   17     5.5    80.0    NaN
# 1   Jessica   16     6.0    85.0    NaN
# 2     Somto   17     5.4    70.0    NaN
# 3     Edith   18     5.9    60.0    NaN
# 4      Liza   16     5.6    76.0    NaN
# 5   Madonna   18     5.5    66.0    NaN
# 6      Waje   17     6.1    87.0    NaN
# 7      Tola   20     6.0    95.0    NaN
# 8     Aisha   19     5.7    50.0    NaN
# 9    Latifa   17     5.5    49.0    NaN
# 10  Chinedu   19     5.7     NaN   74.0
# 11     Liam   16     5.9     NaN   87.0
# 12     Wale   18     5.8     NaN   75.0
# 13   Gbenga   17     6.1     NaN   68.0
# 14   Abiola   20     5.9     NaN   66.0
# 15     Kola   19     5.5     NaN   78.0
# 16    Kunle   16     6.1     NaN   87.0
# 17   George   18     5.4     NaN   98.0
# 18   Thomas   17     5.8     NaN   54.0
# 19   Wesley   19     5.7     NaN   60.0
