# %% [markdown]
# ![diagram-export-13-03-2026-16_05_53.png](attachment:cbd763cf-02a7-49a3-bdf6-0c22b61ce366.png)

# %%
# WEEK-2 PUSEDOCODE 1B



PRINT "Enter the Items"

INPUT Item cost

COMPUTE Total

PRINT "Cash/Card"

INPUT cash/ card

PROCESS Payment process

READ Security check

# %% [markdown]
# ![diagram-export-13-03-2026-17_09_55.png](attachment:4956b8ed-21a1-4397-bd8d-3b58a6cb2f1e.png)

# %% [markdown]
# ![diagram-export-13-03-2026-17_31_49.png](attachment:9784f6a5-b510-49b6-9ff3-065f58d5883f.png)
