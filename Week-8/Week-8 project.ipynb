# %%
import tkinter as tk
from tkinter import messagebox


# Parent class
class Zenith:
    def unique_services(self):
        return "Unique services not defined"

    def mutual_services(self):
        return [
            "Lines of credit",
            "Investment management and accounts",
            "Insurance"
        ]

# Subclass

class RetailBanking(Zenith):
    def unique_services(self):
        return [
            "Retirement and education accounts:,
            "Loans and mortages",
            "Checking and savings"
        ]

# subclass for commercial

class CommercialBanking(Zenuth):
    def unique_services(self):
        return [
            "Advisory Services"
        ]

def get_division_object(division):
    division = division.lower()

    if division == "retail":
        return RetailBanking()
    elif division == "global":
        return GlobalBanking()
    elif division == "commercial":
        return CommercialBanking()

    else:
        return None


## GUI interface
